# %% [markdown]
# <a href="https://colab.research.google.com/github/delafarahita/PCVK_Ganjil_2024/blob/main/Dela_Farahita_Zain_Modul_2_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Praktikum**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# 1. Import folder yang ada di Drive

# %%
from google.colab import drive

# Acessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_Ganjil_2024/Modul2/Amu.jpg')
plt.imshow(img)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# 3. Menampilkan citra Grayscale,melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_Ganjil_2024/Modul2/Amu.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#Simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_Ganjil_2024/Modul2/Amu.jpg', img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.

# %%
cv.circle(black_img, center=(400,400), radius=20, color=(255,0,0), thickness=100)
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
verticles = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
verticles
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = verticles.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2,[pts],isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **Pertanyaan**

# %% [markdown]
# # 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?

# %% [markdown]
# Tanpa matplotlib, gambar ditampilkan di jendela terpisah. Sedangkan dengan matplotlib, gambar muncul langsung di dalam notebook.

# %% [markdown]
# # 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?

# %% [markdown]
# int16 hemat memori (rentang -32.768 sampai dengan 32.767). int32 bisa menyimpan nilai lebih besar tapi pakai lebih banyak memori. Tidak ada perbedaan visual untuk gambar hitam.

# %% [markdown]
# # 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
# from google.colab.patches import cv2_imshow \
# from skimage import io

# %% [markdown]
# Kode tersebut digunakan di Google Colab untuk menampilkan gambar yang diproses menggunakan OpenCV (cv2.imshow()) dalam notebook. Karena cv2.imshow() tidak kompatibel di Google Colab

# %% [markdown]
# # 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# skimage.io digunakan untuk membaca dan menulis gambar dalam berbagai format.

# %% [markdown]
# # **TUGAS**

# %% [markdown]
# # 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?

# %% [markdown]
# Tidak, menggunakan figsize hanya mengubah tampilan ukuran gambar pada plot, bukan resolusi atau jumlah pixel gambar. Pixel sebenarnya tetap sama.

# %% [markdown]
# # 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

red_channel = img_rgb[:,:,0]
green_channel = img_rgb[:,:,1]
blue_channel = img_rgb[:,:,2]

red_blue_channel = cv.merge([red_channel, blue_channel, blue_channel])
green_blue_channel = cv.merge([green_channel, blue_channel, blue_channel])

plt.figure(figsize=(10,15))
plt.subplot(3, 1, 1)
plt.imshow(red_blue_channel)
plt.title('Red-Blue Channel')
plt.axis('off')

plt.subplot(3, 1, 2)
plt.imshow(green_blue_channel)
plt.title('Green-Blue Channel')
plt.axis('off')

plt.subplot(3, 1, 3)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')

plt.show()

# %% [markdown]
# # 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
cropped_img = img_rgb[20:116, 25:121]
plt.imshow(cropped_img)

# %% [markdown]
# # 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
cropped_img = img_rgb[5:31, :, 0]
plt.imshow(cropped_img, cmap='gray')

# %% [markdown]
# # 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %%
# Buat gambar kosong (kanvas) berukuran 512x512 dengan 3 channel (RGB)
height, width = 512, 512
image = np.zeros((height, width, 3), dtype=np.uint8)

# Fungsi untuk menghasilkan warna acak
def random_color():
    return np.random.randint(0, 256, size=3).tolist()

# Fungsi untuk menghasilkan posisi dan ukuran acak
def random_rect_params():
    x = np.random.randint(0, width - 50)
    y = np.random.randint(0, height - 50)
    w = np.random.randint(30, 100)
    h = np.random.randint(30, 100)
    return x, y, w, h

# Gambarkan 5 kotak dengan warna dan ukuran acak
for _ in range(5):
    x, y, w, h = random_rect_params()
    color = random_color()
    cv.rectangle(image, (x, y), (x + w, y + h), color, -1)

# Tampilkan gambar
plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.title('Random Colored Rectangles')
plt.axis('on')
plt.show()

# %% [markdown]
# # 6. Tampilkan image dengan posisi terbalik!

# %%
flipped_vertical = cv.flip(img, 0)
flipped_horizontal = cv.flip(img, 1)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(flipped_vertical)
plt.title('Vertically Flipped Image')
plt.axis('on')

plt.subplot(1, 2, 2)
plt.imshow(flipped_horizontal)
plt.title('Horizontally Flipped Image')
plt.axis('on')

plt.show()

# %% [markdown]
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# # 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto).

# %%
img2 = cv.imread('/content/drive/MyDrive/PCVK_Ganjil_2024/Modul2/Demo-mitra.jpeg')
img2 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)
cv.rectangle(img2, pt1=(760, 1200), pt2=(960, 960), color=(255, 0, 0), thickness=15)
cv.circle(img2, center=(860, 1080), radius=50, color=(255, 0, 0), thickness=8)
plt.imshow(img2)

# %% [markdown]
# # 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
cv.rectangle(img2, pt1=(80,2300), pt2=(500,2000), color=(255,0,0), thickness=15)
plt.imshow(img2)

# %% [markdown]
# # 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
# Menambahkan teks nama file
text = 'Dela'  # Teks yang ingin ditampilkan
font = cv.FONT_HERSHEY_SIMPLEX  # Jenis font
font_scale = 5  # Ukuran font
font_color = (255, 0, 0)  # Warna teks (hijau)
thickness = 5  # Ketebalan garis teks
location = (100, 2250)  # Posisi teks di gambar (x, y)

# Tambahkan teks ke citra
cv.putText(img2, text, location, font, font_scale, font_color, thickness, cv.LINE_AA)
plt.imshow(img2)
